# %%
# image+svm+pm+fscore with ficher
import rasterio
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Users\pc\jupyter\5 profile\concatenated_full.csv')

os.chdir(r'C:\Users\pc\Desktop\PFE\case 4')
data = data[data.iloc[:, -1] != 0]
data = data.drop(data.index[-1])
data = data[(data.iloc[:, -1] >= 1) & (data.iloc[:, -1] <= 4)]
# Displaying the filled DataFrame
display(data.head(10).style.format("{0:.2f}").set_caption("Few lines of the dataset:"))

# Checking the count of missing data and the shape of the DataFrame
print('Missing Data:', data.isna().sum().sum(), 'Shape is:', data.shape)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4e078">
#   <caption>Few lines of the dataset:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e078_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_4e078_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_4e078_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_4e078_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_4e078_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_4e078_level0_col5" class="col_heading level0 col5" >0.1</th>
#       <th id="T_4e078_level0_col6" class="col_heading level0 col6" >1.1</th>
#       <th id="T_4e078_level0_col7" class="col_heading level0 col7" >2.1</th>
#       <th id="T_4e078_level0_col8" class="col_heading level0 col8" >3.1</th>
#       <th id="T_4e078_level0_col9" class="col_heading level0 col9" >4.1</th>
#       <th id="T_4e078_level0_col10" class="col_heading level0 col10" >0.2</th>
#       <th id="T_4e078_level0_col11" class="col_heading level0 col11" >1.2</th>
#       <th id="T_4e078_level0_col12" class="col_heading level0 col12" >2.2</th>
#       <th id="T_4e078_level0_col13" class="col_heading level0 col13" >3.2</th>
#       <th id="T_4e078_level0_col14" class="col_heading level0 col14" >4.2</th>
#       <th id="T_4e078_level0_col15" class="col_heading level0 col15" >0.3</th>
#       <th id="T_4e078_level0_col16" class="col_heading level0 col16" >1.3</th>
#       <th id="T_4e078_level0_col17" class="col_heading level0 col17" >2.3</th>
#       <th id="T_4e078_level0_col18" class="col_heading level0 col18" >3.3</th>
#       <th id="T_4e078_level0_col19" class="col_heading level0 col19" >4.3</th>
#       <th id="T_4e078_level0_col20" class="col_heading level0 col20" >0.4</th>
#       <th id="T_4e078_level0_col21" class="col_heading level0 col21" >1.4</th>
#       <th id="T_4e078_level0_col22" class="col_heading level0 col22" >2.4</th>
#       <th id="T_4e078_level0_col23" class="col_heading level0 col23" >3.4</th>
#       <th id="T_4e078_level0_col24" class="col_heading level0 col24" >4.4</th>
#       <th id="T_4e078_level0_col25" class="col_heading level0 col25" >0.5</th>
#       <th id="T_4e078_level0_col26" class="col_heading level0 col26" >1.5</th>
#       <th id="T_4e078_level0_col27" class="col_heading level0 col27" >2.5</th>
#       <th id="T_4e078_level0_col28" class="col_heading level0 col28" >3.5</th>
#       <th id="T_4e078_level0_col29" class="col_heading level0 col29" >4.5</th>
#       <th id="T_4e078_level0_col30" class="col_heading level0 col30" >0.6</th>
#       <th id="T_4e078_level0_col31" class="col_heading level0 col31" >1.6</th>
#       <th id="T_4e078_level0_col32" class="col_heading level0 col32" >2.6</th>
#       <th id="T_4e078_level0_col33" class="col_heading level0 col33" >3.6</th>
#       <th id="T_4e078_level0_col34" class="col_heading level0 col34" >4.6</th>
#       <th id="T_4e078_level0_col35" class="col_heading level0 col35" >0.7</th>
#       <th id="T_4e078_level0_col36" class="col_heading level0 col36" >1.7</th>
#       <th id="T_4e078_level0_col37" class="col_heading level0 col37" >2.7</th>
#       <th id="T_4e078_level0_col38" class="col_heading level0 col38" >3.7</th>
#       <th id="T_4e078_level0_col39" class="col_heading level0 col39" >4.7</th>
#       <th id="T_4e078_level0_col40" class="col_heading level0 col40" >0.8</th>
#       <th id="T_4e078_level0_col41" class="col_heading level0 col41" >1.8</th>
#       <th id="T_4e078_level0_col42" class="col_heading level0 col42" >2.8</th>
#       <th id="T_4e078_level0_col43" class="col_heading level0 col43" >3.8</th>
#       <th id="T_4e078_level0_col44" class="col_heading level0 col44" >4.8</th>
#       <th id="T_4e078_level0_col45" class="col_heading level0 col45" >0.9</th>
#       <th id="T_4e078_level0_col46" class="col_heading level0 col46" >1.9</th>
#       <th id="T_4e078_level0_col47" class="col_heading level0 col47" >2.9</th>
#       <th id="T_4e078_level0_col48" class="col_heading level0 col48" >3.9</th>
#       <th id="T_4e078_level0_col49" class="col_heading level0 col49" >4.9</th>
#       <th id="T_4e078_level0_col50" class="col_heading level0 col50" >0.10</th>
#       <th id="T_4e078_level0_col51" class="col_heading level0 col51" >1.10</th>
#       <th id="T_4e078_level0_col52" class="col_heading level0 col52" >2.10</th>
#       <th id="T_4e078_level0_col53" class="col_heading level0 col53" >3.10</th>
#       <th id="T_4e078_level0_col54" class="col_heading level0 col54" >4.10</th>
#       <th id="T_4e078_level0_col55" class="col_heading level0 col55" >5</th>
#       <th id="T_4e078_level0_col56" class="col_heading level0 col56" >6</th>
#       <th id="T_4e078_level0_col57" class="col_heading level0 col57" >7</th>
#       <th id="T_4e078_level0_col58" class="col_heading level0 col58" >8</th>
#       <th id="T_4e078_level0_col59" class="col_heading level0 col59" >9</th>
#       <th id="T_4e078_level0_col60" class="col_heading level0 col60" >0.11</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e078_level0_row0" class="row_heading level0 row0" >2362</th>
#       <td id="T_4e078_row0_col0" class="data row0 col0" >1792.00</td>
#       <td id="T_4e078_row0_col1" class="data row0 col1" >1820.00</td>
#       <td id="T_4e078_row0_col2" class="data row0 col2" >1820.00</td>
#       <td id="T_4e078_row0_col3" class="data row0 col3" >1820.00</td>
#       <td id="T_4e078_row0_col4" class="data row0 col4" >1792.00</td>
#       <td id="T_4e078_row0_col5" class="data row0 col5" >2174.00</td>
#       <td id="T_4e078_row0_col6" class="data row0 col6" >2200.00</td>
#       <td id="T_4e078_row0_col7" class="data row0 col7" >2154.00</td>
#       <td id="T_4e078_row0_col8" class="data row0 col8" >2154.00</td>
#       <td id="T_4e078_row0_col9" class="data row0 col9" >2154.00</td>
#       <td id="T_4e078_row0_col10" class="data row0 col10" >2484.00</td>
#       <td id="T_4e078_row0_col11" class="data row0 col11" >2484.00</td>
#       <td id="T_4e078_row0_col12" class="data row0 col12" >2484.00</td>
#       <td id="T_4e078_row0_col13" class="data row0 col13" >2484.00</td>
#       <td id="T_4e078_row0_col14" class="data row0 col14" >2484.00</td>
#       <td id="T_4e078_row0_col15" class="data row0 col15" >2726.00</td>
#       <td id="T_4e078_row0_col16" class="data row0 col16" >2730.00</td>
#       <td id="T_4e078_row0_col17" class="data row0 col17" >2730.00</td>
#       <td id="T_4e078_row0_col18" class="data row0 col18" >2730.00</td>
#       <td id="T_4e078_row0_col19" class="data row0 col19" >2726.00</td>
#       <td id="T_4e078_row0_col20" class="data row0 col20" >2784.00</td>
#       <td id="T_4e078_row0_col21" class="data row0 col21" >2784.00</td>
#       <td id="T_4e078_row0_col22" class="data row0 col22" >2784.00</td>
#       <td id="T_4e078_row0_col23" class="data row0 col23" >2784.00</td>
#       <td id="T_4e078_row0_col24" class="data row0 col24" >2784.00</td>
#       <td id="T_4e078_row0_col25" class="data row0 col25" >2852.00</td>
#       <td id="T_4e078_row0_col26" class="data row0 col26" >2852.00</td>
#       <td id="T_4e078_row0_col27" class="data row0 col27" >2852.00</td>
#       <td id="T_4e078_row0_col28" class="data row0 col28" >2852.00</td>
#       <td id="T_4e078_row0_col29" class="data row0 col29" >2852.00</td>
#       <td id="T_4e078_row0_col30" class="data row0 col30" >2770.00</td>
#       <td id="T_4e078_row0_col31" class="data row0 col31" >2770.00</td>
#       <td id="T_4e078_row0_col32" class="data row0 col32" >2760.00</td>
#       <td id="T_4e078_row0_col33" class="data row0 col33" >2760.00</td>
#       <td id="T_4e078_row0_col34" class="data row0 col34" >2760.00</td>
#       <td id="T_4e078_row0_col35" class="data row0 col35" >2795.00</td>
#       <td id="T_4e078_row0_col36" class="data row0 col36" >2795.00</td>
#       <td id="T_4e078_row0_col37" class="data row0 col37" >2795.00</td>
#       <td id="T_4e078_row0_col38" class="data row0 col38" >2795.00</td>
#       <td id="T_4e078_row0_col39" class="data row0 col39" >2795.00</td>
#       <td id="T_4e078_row0_col40" class="data row0 col40" >3220.00</td>
# Missing Data: 0 Shape is: (9132, 61)

# %%
data_array = np.array([data])
print(data_array.shape)
x = data_array[0, :, 0:60]
y = data_array[0, :, 60]
# Out:
# (1, 9132, 61)

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, cohen_kappa_score, accuracy_score


############################  Split data ######
seed=42
y_train,y_test,x_train,x_test=train_test_split(y,x,test_size=0.20,random_state=42)
print("x_train : ",x_train.shape)
print("y_train : ",y_train.shape)
print("x_test  : ",x_test.shape)
print("y_test  : ",y_test.shape)
# Out:
# x_train :  (7305, 60)
# y_train :  (7305,)
# x_test  :  (1827, 60)
# y_test  :  (1827,)

# %%
import tensorflow as tf
x_train=tf.keras.utils.normalize(x_train,axis=1)
x_test=tf.keras.utils.normalize(x_test,axis=1)

# %%
from sklearn import svm
# apply SVM to get a classified image
clf = svm.SVC(kernel='rbf',C=1.0,gamma='scale')
clf.fit(x_train,y_train)
y_predicted= clf.predict(x_test)
accuracy=accuracy_score(y_test,y_predicted)
print(accuracy)
# Out:
# 0.9896004378762999

# %%
from matplotlib.colors import ListedColormap
# Load the data from the CSV file
data1 = pd.read_csv(r'C:\Users\pc\jupyter\5 profile\pm and image.csv')

# Normalize the data
data1 = tf.keras.utils.normalize(data1, axis=1)

# Predict using the model
predicted = clf.predict(data1)

# Reshape the predicted classes to match image dimensions
height, width = 1000, 1000
predicted_image = np.reshape(predicted, (height, width))
# Define the custom color palette for each class
colors = ['blue', 'green', 'yellow', 'red']
cmap = ListedColormap(colors)
# Display the image
plt.matshow(predicted_image, cmap=cmap)
plt.colorbar()
plt.show()

# %%
predicted_df=pd.DataFrame(predicted_image)
predicted_flat=predicted_image.flatten()
predicted_df= pd.DataFrame({'Predicted':predicted_flat})

# %%
df1=pd.read_csv(r'C:\Users\pc\jupyter\5 profile\pm and image.csv')
data=pd.concat([df1,predicted_df],axis=1)
print('Missing Data:', data.isna().sum().sum(), 'Shape is:', data.shape)
# Out:
# Missing Data: 0 Shape is: (1000000, 61)

# %%
data_array = np.array([data])
print(data_array.shape)
x = data_array[0, :, 0:60]
y = data_array[0, :, 60]
# Out:
# (1, 1000000, 61)

# %%
# calcule de Fscore et ficher
from sklearn.feature_selection import f_classif
from skimage.filters import threshold_otsu
fit=f_classif(x,y)[0]
sorted_indices=np.argsort(fit)[::-1]
sorted_fscores=fit[sorted_indices]
print(sorted_indices,sorted_fscores,sep='\n\n')
# ficher
def fisher_threshold(F_scores):
  """
  This function applies the Ficher thresholding method on a list of F scores.

  Args:
      F_scores: A sorted list of F scores.

  Returns:
    the Ficher threshold
  """
  # Calculate the number of features
  num_features = len(F_scores)
  fisher_scores=[]
  for i in range(num_features):
          if i ==0:
              moy1=sorted_fscores[0]
              moy2=(1/(num_features-1))*sum(sorted_fscores[1:])
          elif i ==59:
              moy1=(1/i+1)*sum(sorted_fscores[:i+1])
              moy2=0
              
          else:
              moy1=(1/i+1)*sum(sorted_fscores[:i+1])
              moy2=(1/(num_features-i))*sum(sorted_fscores[i+1:])
              
          
          
          # Calculate the variance of F scores
          var1= sum((sorted_fscores[:i+1] - moy1)**2)
          var2=sum((sorted_fscores[i+1:] - moy2)**2)
          
          
          fisher=abs(moy1-moy2)/abs(var1-var2)
          fisher_scores.append(fisher)
  return fisher_scores
# list of ficher scores
fisher_scores=fisher_threshold(sorted_fscores)
# max of ficher scores' index
F=fisher_scores.index(max(fisher_scores))
# corresponding value of F-score
thresh=sorted_fscores[F]
print(thresh)
# Out:
# [35 45 40 36 25 46 39 30 20 38 26 31 49 29 10 48 28 21 37 57 34 24 41 11
#  33 15 23 44 55 27 59 47 14 56 32 43 54 22 13 16  0 58 42 19  1  5 52 12
#  18  4  6  3 17 53  9  8 50  2  7 51]
#
# [592319.81955537 576516.80065667 561697.27677453 556210.59986416
#  546563.0212363  541076.16058952 538318.63909551 532910.07170308
#  519610.4644484  512701.19721525 508045.3056631  506291.72863517
#  506125.48799669 496605.69542904 494507.04530262 472571.15239585
#  467990.59654059 466635.05003728 455082.06316984 455082.06316984
#  453929.17516888 453034.04256117 451951.22850522 447433.51203385
#  440569.72445855 433343.8114266  418896.73263243 408514.66716264
#  407840.84950328 407840.84950328 405685.31851588 405685.31851588
#  392715.13246987 367705.58018193 367705.58018193 363688.55556314
#  350199.85958256 350199.85958256 344524.41570615 334383.84117921
#  328348.26510445 306084.05573006 306084.05573006 297580.23852441
#  276303.32289141 269676.80650817 254288.04109773 254288.04109773
#  251668.89800834 250322.94814441 227021.06425304 211366.89951588
#  195935.00817954 195935.00817954 168776.26079473 152659.23693262
#  151829.18976338 151829.18976338 122704.74738615 122704.74738615]
# 576516.800656668

# %%
taken=[]
for i in range(len(sorted_fscores)):
    if sorted_fscores[i]>=thresh:
        taken.append(sorted_indices[i])

print(taken)
# Out:
# [35, 45]

# %%
x1=x[:,taken]
print(x1.shape)
x1=pd.DataFrame(x1,columns=taken)
x2=pd.read_csv(r'C:\Users\pc\Desktop\PFE\case1\image_test2.csv',header=None)
print(x1)
x1= pd.concat([x1,x2],axis=1)
print('Missing Data:', x1.isna().sum().sum(), 'Shape is:', x1.shape)
print(x1)
x1.to_csv(r'selected ficher.csv',index=False)
# Out:
# (1000000, 2)
#             35      45
# 0       1106.0  1074.0
# 1       1106.0  1074.0
# 2       1106.0  1074.0
# 3       1104.0  1074.0
# 4       1104.0  1074.0
# ...        ...     ...
# 999995  4688.0  1605.0
# 999996  4688.0  1605.0
# 999997  4688.0  1605.0
# 999998  4688.0  1605.0
# 999999  4688.0  1605.0
#
# [1000000 rows x 2 columns]
# Missing Data: 0 Shape is: (1000000, 12)
#             35      45    0     1     2     3     4     5     6     7     8   \
# 0       1106.0  1074.0  1262  1263  1130  1108  1095  1106  1090  1110  1077
# 1       1106.0  1074.0  1240  1268  1130  1119  1105  1091  1123  1118  1085
# 2       1106.0  1074.0  1278  1273  1127  1119  1105  1091  1128  1118  1085
# 3       1104.0  1074.0  1260  1253  1122  1114  1096  1092  1100  1096  1086
# 4       1104.0  1074.0  1220  1248  1139  1114  1096  1092  1104  1096  1086
# ...        ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 999995  4688.0  1605.0  1172  1461  1244  1914  3910  4480  4856  4688  2304
# 999996  4688.0  1605.0  1181  1504  1261  1914  3910  4480  4892  4688  2304
# 999997  4688.0  1605.0  1148  1500  1260  1963  4076  4662  4752  4816  2338
# 999998  4688.0  1605.0  1167  1511  1266  1963  4076  4662  4783  4816  2338
# 999999  4688.0  1605.0  1194  1523  1272  2028  4468  5066  5412  5288  2351
#
#           9
# 0       1067
# 1       1068
# 2       1068
# 3       1074
# 4       1074
# ...      ...
# 999995  1589
# 999996  1589
# 999997  1606
# 999998  1606
# 999999  1611
#
# [1000000 rows x 12 columns]

# %%
# Charger les fichiers CSV
df1 = pd.read_csv(r'selected ficher.csv')
df2 = pd.read_csv(r'C:\Users\pc\jupyter\R1.csv')
result = pd.concat([df1, df2], axis=1)
print(result)
# Enregistrer le résultat dans un nouveau fichier CSV
result.to_csv(r'fscore ficher.csv', index=False)

# %%
data = result[result.iloc[:, -1] != 0]
data = data.drop(data.index[-1])
# Displaying the filled DataFrame

display(data.head(10).style.format("{0:}").set_caption("Few lines of the dataset:"))
# Checking the count of missing data and the shape of the DataFrame
print('Missing Data:', data.isna().sum().sum(), 'Shape is:', data.shape)
# Out:
# <style type="text/css">
# </style>
# <table id="T_46148">
#   <caption>Few lines of the dataset:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46148_level0_col0" class="col_heading level0 col0" >35</th>
#       <th id="T_46148_level0_col1" class="col_heading level0 col1" >45</th>
#       <th id="T_46148_level0_col2" class="col_heading level0 col2" >1262</th>
#       <th id="T_46148_level0_col3" class="col_heading level0 col3" >1263</th>
#       <th id="T_46148_level0_col4" class="col_heading level0 col4" >1130</th>
#       <th id="T_46148_level0_col5" class="col_heading level0 col5" >1108</th>
#       <th id="T_46148_level0_col6" class="col_heading level0 col6" >1095</th>
#       <th id="T_46148_level0_col7" class="col_heading level0 col7" >1106</th>
#       <th id="T_46148_level0_col8" class="col_heading level0 col8" >1090</th>
#       <th id="T_46148_level0_col9" class="col_heading level0 col9" >1110</th>
#       <th id="T_46148_level0_col10" class="col_heading level0 col10" >1077</th>
#       <th id="T_46148_level0_col11" class="col_heading level0 col11" >1067</th>
#       <th id="T_46148_level0_col12" class="col_heading level0 col12" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46148_level0_row0" class="row_heading level0 row0" >2362</th>
#       <td id="T_46148_row0_col0" class="data row0 col0" >2795.0</td>
#       <td id="T_46148_row0_col1" class="data row0 col1" >2792.0</td>
#       <td id="T_46148_row0_col2" class="data row0 col2" >1817.0</td>
#       <td id="T_46148_row0_col3" class="data row0 col3" >2178.0</td>
#       <td id="T_46148_row0_col4" class="data row0 col4" >2474.0</td>
#       <td id="T_46148_row0_col5" class="data row0 col5" >2750.0</td>
#       <td id="T_46148_row0_col6" class="data row0 col6" >2869.0</td>
#       <td id="T_46148_row0_col7" class="data row0 col7" >2838.0</td>
#       <td id="T_46148_row0_col8" class="data row0 col8" >2788.0</td>
#       <td id="T_46148_row0_col9" class="data row0 col9" >2832.0</td>
#       <td id="T_46148_row0_col10" class="data row0 col10" >3367.0</td>
#       <td id="T_46148_row0_col11" class="data row0 col11" >3069.0</td>
#       <td id="T_46148_row0_col12" class="data row0 col12" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_46148_level0_row1" class="row_heading level0 row1" >3361</th>
#       <td id="T_46148_row1_col0" class="data row1 col0" >2795.0</td>
#       <td id="T_46148_row1_col1" class="data row1 col1" >2792.0</td>
#       <td id="T_46148_row1_col2" class="data row1 col2" >1894.0</td>
#       <td id="T_46148_row1_col3" class="data row1 col3" >2288.0</td>
#       <td id="T_46148_row1_col4" class="data row1 col4" >2516.0</td>
#       <td id="T_46148_row1_col5" class="data row1 col5" >2730.0</td>
#       <td id="T_46148_row1_col6" class="data row1 col6" >2784.0</td>
#       <td id="T_46148_row1_col7" class="data row1 col7" >2852.0</td>
#       <td id="T_46148_row1_col8" class="data row1 col8" >2864.0</td>
#       <td id="T_46148_row1_col9" class="data row1 col9" >2795.0</td>
#       <td id="T_46148_row1_col10" class="data row1 col10" >3220.0</td>
#       <td id="T_46148_row1_col11" class="data row1 col11" >2955.0</td>
#       <td id="T_46148_row1_col12" class="data row1 col12" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_46148_level0_row2" class="row_heading level0 row2" >3362</th>
#       <td id="T_46148_row2_col0" class="data row2 col0" >2795.0</td>
#       <td id="T_46148_row2_col1" class="data row2 col1" >2792.0</td>
#       <td id="T_46148_row2_col2" class="data row2 col2" >1844.0</td>
#       <td id="T_46148_row2_col3" class="data row2 col3" >2208.0</td>
#       <td id="T_46148_row2_col4" class="data row2 col4" >2462.0</td>
#       <td id="T_46148_row2_col5" class="data row2 col5" >2750.0</td>
#       <td id="T_46148_row2_col6" class="data row2 col6" >2869.0</td>
#       <td id="T_46148_row2_col7" class="data row2 col7" >2838.0</td>
#       <td id="T_46148_row2_col8" class="data row2 col8" >2924.0</td>
#       <td id="T_46148_row2_col9" class="data row2 col9" >2832.0</td>
#       <td id="T_46148_row2_col10" class="data row2 col10" >3367.0</td>
#       <td id="T_46148_row2_col11" class="data row2 col11" >3069.0</td>
#       <td id="T_46148_row2_col12" class="data row2 col12" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_46148_level0_row3" class="row_heading level0 row3" >3363</th>
#       <td id="T_46148_row3_col0" class="data row3 col0" >2832.0</td>
#       <td id="T_46148_row3_col1" class="data row3 col1" >2792.0</td>
#       <td id="T_46148_row3_col2" class="data row3 col2" >1804.0</td>
#       <td id="T_46148_row3_col3" class="data row3 col3" >2186.0</td>
#       <td id="T_46148_row3_col4" class="data row3 col4" >2430.0</td>
#       <td id="T_46148_row3_col5" class="data row3 col5" >2750.0</td>
#       <td id="T_46148_row3_col6" class="data row3 col6" >2869.0</td>
#       <td id="T_46148_row3_col7" class="data row3 col7" >2838.0</td>
#       <td id="T_46148_row3_col8" class="data row3 col8" >2988.0</td>
#       <td id="T_46148_row3_col9" class="data row3 col9" >2832.0</td>
#       <td id="T_46148_row3_col10" class="data row3 col10" >3367.0</td>
#       <td id="T_46148_row3_col11" class="data row3 col11" >3069.0</td>
#       <td id="T_46148_row3_col12" class="data row3 col12" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_46148_level0_row4" class="row_heading level0 row4" >3364</th>
#       <td id="T_46148_row4_col0" class="data row4 col0" >2832.0</td>
#       <td id="T_46148_row4_col1" class="data row4 col1" >2792.0</td>
#       <td id="T_46148_row4_col2" class="data row4 col2" >1838.0</td>
#       <td id="T_46148_row4_col3" class="data row4 col3" >2260.0</td>
#       <td id="T_46148_row4_col4" class="data row4 col4" >2528.0</td>
#       <td id="T_46148_row4_col5" class="data row4 col5" >2797.0</td>
#       <td id="T_46148_row4_col6" class="data row4 col6" >2922.0</td>
#       <td id="T_46148_row4_col7" class="data row4 col7" >2899.0</td>
#       <td id="T_46148_row4_col8" class="data row4 col8" >3036.0</td>
#       <td id="T_46148_row4_col9" class="data row4 col9" >2953.0</td>
#       <td id="T_46148_row4_col10" class="data row4 col10" >3482.0</td>
#       <td id="T_46148_row4_col11" class="data row4 col11" >3113.0</td>
#       <td id="T_46148_row4_col12" class="data row4 col12" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_46148_level0_row5" class="row_heading level0 row5" >4360</th>
#       <td id="T_46148_row5_col0" class="data row5 col0" >2840.0</td>
#       <td id="T_46148_row5_col1" class="data row5 col1" >2792.0</td>
#       <td id="T_46148_row5_col2" class="data row5 col2" >1868.0</td>
#       <td id="T_46148_row5_col3" class="data row5 col3" >2236.0</td>
#       <td id="T_46148_row5_col4" class="data row5 col4" >2520.0</td>
#       <td id="T_46148_row5_col5" class="data row5 col5" >2721.0</td>
#       <td id="T_46148_row5_col6" class="data row5 col6" >2834.0</td>
#       <td id="T_46148_row5_col7" class="data row5 col7" >2887.0</td>
#       <td id="T_46148_row5_col8" class="data row5 col8" >2874.0</td>
#       <td id="T_46148_row5_col9" class="data row5 col9" >2895.0</td>
#       <td id="T_46148_row5_col10" class="data row5 col10" >3295.0</td>
#       <td id="T_46148_row5_col11" class="data row5 col11" >2905.0</td>
#       <td id="T_46148_row5_col12" class="data row5 col12" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_46148_level0_row6" class="row_heading level0 row6" >4361</th>
#       <td id="T_46148_row6_col0" class="data row6 col0" >2895.0</td>
#       <td id="T_46148_row6_col1" class="data row6 col1" >2792.0</td>
#       <td id="T_46148_row6_col2" class="data row6 col2" >1816.0</td>
#       <td id="T_46148_row6_col3" class="data row6 col3" >2256.0</td>
#       <td id="T_46148_row6_col4" class="data row6 col4" >2476.0</td>
#       <td id="T_46148_row6_col5" class="data row6 col5" >2721.0</td>
#       <td id="T_46148_row6_col6" class="data row6 col6" >2834.0</td>
#       <td id="T_46148_row6_col7" class="data row6 col7" >2887.0</td>
#       <td id="T_46148_row6_col8" class="data row6 col8" >2982.0</td>
#       <td id="T_46148_row6_col9" class="data row6 col9" >2895.0</td>
#       <td id="T_46148_row6_col10"
# Missing Data: 0 Shape is: (9132, 13)

# %%
data_array = np.array([data])
print(data_array.shape)
x = data_array[0, :, 0:12]
y = data_array[0, :, 12]
# Out:
# (1, 9132, 13)

# %%
import rasterio
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, cohen_kappa_score, accuracy_score
from keras.models import Sequential
from keras.layers import Dense, Activation,Dropout,GlobalMaxPooling1D
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import layers

# %%
############################  Split data ######
seed=42
y_train,y_test,x_train,x_test=train_test_split(y,x,test_size=0.20,random_state=42)
print("x_train : ",x_train.shape)
print("y_train : ",y_train.shape)
print("x_test  : ",x_test.shape)
print("y_test  : ",y_test.shape)
# Out:
# x_train :  (7305, 12)
# y_train :  (7305,)
# x_test  :  (1827, 12)
# y_test  :  (1827,)

# %%
x_train=tf.keras.utils.normalize(x_train,axis=1)
x_test=tf.keras.utils.normalize(x_test,axis=1)

################## Reshape the Data ###########################

sample_size =x_train.shape[0] # number of samples in train set
time_steps  =x_train.shape[1] # number of features in train set
input_dimension = 1               # each feature is represented by 1 number

x_train_reshaped = x_train.reshape(sample_size,time_steps,input_dimension)
x_test_reshaped = x_test.reshape(x_test.shape[0],x_test.shape[1],1)
print("After reshape train data set shape:\n", x_train_reshaped.shape)
print("1 Sample shape:\n",x_train_reshaped[0].shape)
print("An example sample:\n", x_train_reshaped[0])


print("After reshape test data set shape:\n", x_test_reshaped.shape)
print("1 Sample shape:\n",x_test_reshaped[0].shape)
print("An example sample:\n", x_test_reshaped[0])

# reshape for CNN model (not needed for cnn)
train_shape = x_train_reshaped.shape
input_shape = (train_shape[1], train_shape[2])
# Out:
# After reshape train data set shape:
#  (7305, 12, 1)
# 1 Sample shape:
#  (12, 1)
# An example sample:
#  [[0.42474882]
#  [0.12778706]
#  [0.08734169]
#  [0.10843417]
#  [0.08871887]
#  [0.13916685]
#  [0.36922705]
#  [0.43105482]
#  [0.44156482]
#  [0.43409909]
#  [0.18802021]
#  [0.12539513]]
# After reshape test data set shape:
#  (1827, 12, 1)
# 1 Sample shape:
#  (12, 1)
# An example sample:
#  [[0.30892714]
#  [0.32085541]
#  [0.19900585]
#  [0.22709014]
#  [0.2506447 ]
#  [0.2636299 ]
#  [0.28038988]
#  [0.29443202]
#  [0.29669689]
#  [0.30349147]
#  [0.36494472]
#  [0.31541974]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Input
from keras.layers import Conv1D, MaxPooling1D, Dense, Dropout, Flatten, Input, GlobalMaxPooling1D, MaxPooling2D
from keras.callbacks import EarlyStopping
from keras import Model


def build_simple_model():
    model = Sequential()

    # Convolutional layers
    model.add(Conv1D(32, 2, activation="relu", padding='same', input_shape=(12, 1)))
    model.add(Conv1D(32, 2, activation="relu", padding='same'))
    model.add(GlobalMaxPooling1D())
    model.add(Dropout(0.2))

    # Dense layers with regularization
    model.add(Dense(64, activation='relu', kernel_regularizer='l2'))
    model.add(Dropout(0.2))

    # Output layer for multiclass classification
    num_classes = 5  # nbr+1
    model.add(Dense(num_classes, activation='softmax'))

    # Compile the model
    model.compile(
        optimizer='Adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
# Create callback to stop training if loss not decreasing
stop = EarlyStopping(
    monitor='loss',
    patience=5
)
# Reshape the input data
model = build_simple_model()
# Fit the model
result = model.fit(
    x=x_train_reshaped, y=y_train,
    validation_data=(x_test_reshaped, y_test),
    batch_size=1024,
    callbacks=[stop],
    epochs=100,
)
# Out:
# D:\installed\conda\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.1899 - loss: 2.0158 - val_accuracy: 0.2386 - val_loss: 1.9644
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3452 - loss: 1.9507 - val_accuracy: 0.4844 - val_loss: 1.9064
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.3701 - loss: 1.8941 - val_accuracy: 0.5265 - val_loss: 1.8474
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3772 - loss: 1.8345 - val_accuracy: 0.3306 - val_loss: 1.7832
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3655 - loss: 1.7715 - val_accuracy: 0.3306 - val_loss: 1.7138
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3442 - loss: 1.7026 - val_accuracy: 0.3306 - val_loss: 1.6452
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3371 - loss: 1.6426 - val_accuracy: 0.3306 - val_loss: 1.5853
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3432 - loss: 1.5894 - val_accuracy: 0.3306 - val_loss: 1.5400
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3663 - loss: 1.5480 - val_accuracy: 0.3306 - val_loss: 1.5019
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3892 - loss: 1.5140 - val_accuracy: 0.3306 - val_loss: 1.4670
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4138 - loss: 1.4761 - val_accuracy: 0.3306 - val_loss: 1.4287
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4294 - loss: 1.4460 - val_accuracy: 0.6212 - val_loss: 1.3868
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.4591 - loss: 1.4032 - val_accuracy: 0.6229 - val_loss: 1.3391
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4843 - loss: 1.3619 - val_accuracy: 0.6229 - val_loss: 1.2853
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5017 - loss: 1.3133 - val_accuracy: 0.6229 - val_loss: 1.2246
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5345 - loss: 1.2544 - val_accuracy: 0.6229 - val_loss: 1.1603
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5513 - loss: 1.2076 - val_accuracy: 0.6256 - val_loss: 1.1007
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5739 - loss: 1.1534 - val_accuracy: 0.6229 - val_loss: 1.0462
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5831 - loss: 1.1054 - val_accuracy: 0.6196 - val_loss: 1.0022
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6014 - loss: 1.0534 - val_accuracy: 0.6273 - val_loss: 0.9623
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6137 - loss: 1.0246 - val_accuracy: 0.6273 - val_loss: 0.9311
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6252 - loss: 0.9920 - val_accuracy: 0.6333 - val_loss: 0.9071
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6439 - loss: 0.9617 - val_accuracy: 0.7302 - val_loss: 0.8850
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6609 - loss: 0.9352 - val_accuracy: 0.6579 - val_loss: 0.8654
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6667 - loss: 0.9092 - val_accuracy: 0.7077 - val_loss: 0.8475
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6855 - loss: 0.8969 - val_accuracy: 0.7126 - val_loss: 0.8304
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6889 - loss: 0.8751 - val_accuracy: 0.7531 - val_loss: 0.8116
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7071 - loss: 0.8552 - val_accuracy: 0.7685 - val_loss: 0.7922
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7255 - loss: 0.8337 - val_accuracy: 0.7838 - val_loss: 0.7712
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7368 - loss: 0.8129 - val_accuracy: 0.7827 - val_loss: 0.7492
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7410 - loss: 0.7884 - val_accuracy: 0.7969 - val_loss: 0.7246
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7619 - loss: 0.7595 - val_accuracy: 0.8123 - val_loss: 0.6948
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7782 - loss: 0.7280 - val_accuracy: 0.8227 - val_loss: 0.6646
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7773 - loss: 0.7084 - val_accuracy: 0.8303 - val_loss: 0.6336
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7881 - loss: 0.6692 - val_accuracy: 0.8331 - val_loss: 0.6034
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7978 - loss: 0.6444 - val_accuracy: 0.8402 - val_loss: 0.5740
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8068 - loss: 0.6119 - val_accuracy: 0.8358 - val_loss: 0.5468
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8025 - loss: 0.5910 - val_accuracy: 0.8456 - val_loss: 0.5259
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8112 - loss: 0.5708 - val_accuracy: 0.8440 - val_loss: 0.5043
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8134 - loss: 0.5501 - val_accuracy: 0.8462 - val_loss: 0.4882
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8216 - loss: 0.5347 - val_accuracy: 0.8467 - val_loss: 0.4742
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8190 - loss: 0.5151 - val_accuracy: 0.8467 - val_loss: 0.4605
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8275 - loss: 0.5024 - val_accuracy: 0.8489 - val_loss: 0.4497
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8282 - loss: 0.4865 - val_accuracy: 0.8489 - val_loss: 0.4391
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8266 - loss: 0.4782 - val_accuracy: 0.8484 - val_loss: 0.4310
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8271 - loss: 0.4713 - val_accuracy: 0.8495 - val_loss: 0.4229
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8234 - loss: 0.4671 - val_accuracy: 0.8500 - val_loss: 0.4154
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8282 - loss: 0.4588 - val_accuracy: 0.8500 - val_loss: 0.4084
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8306 - loss: 0.4493 - val_accuracy: 0.8506 - val_loss: 0.4028
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8306 - loss: 0.4403 - val_accuracy: 0.8500 - val_loss: 0.3963
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8378 - loss: 0.4309 - val_accuracy: 0.8506 - val_loss: 0.3922
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8385 - loss: 0.4297 - val_accuracy: 0.8506 - val_loss: 0.3864
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8358 - loss: 0.4191 - val_accuracy: 0.8506 - val_loss: 0.3811
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8411 - loss: 0.4159 - val_accuracy: 0.8500 - val_loss: 0.3774
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8346 - loss: 0.4074 - val_accuracy: 0.8495 - val_loss: 0.3721
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8378 - loss: 0.4022 - val_accuracy: 0.8522 - val_loss: 0.3694
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8441 - loss: 0.4001 - val_accuracy: 0.8533 - val_loss: 0.3656
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8485 - loss: 0.3985 - val_accuracy: 0.8522 - val_loss: 0.3615
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8476 - loss: 0.3909 - val_accuracy: 0.8506 - val_loss: 0.3581
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8464 - loss: 0.3898 - val_accuracy: 0.8560 - val_loss: 0.3553
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8440 - loss: 0.3890 - val_accuracy: 0.8533 - val_loss: 0.3524
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8491 - loss: 0.3794 - val_accuracy: 0.8544 - val_loss: 0.3492
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8485 - loss: 0.3751 - val_accuracy: 0.8506 - val_loss: 0.3459
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8480 - loss: 0.3737 - val_accuracy: 0.8566 - val_loss: 0.3429
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8470 - loss: 0.3718 - val_accuracy: 0.8582 - val_loss: 0.3408
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8561 - loss: 0.3638 - val_accuracy: 0.8648 - val_loss: 0.3378
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8528 - loss: 0.3630 - val_accuracy: 0.8588 - val_loss: 0.3347
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8527 - loss: 0.3645 - val_accuracy: 0.8686 - val_loss: 0.3326
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8579 - loss: 0.3595 - val_accuracy: 0.8566 - val_loss: 0.3297
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8580 - loss: 0.3572 - val_accuracy: 0.8670 - val_loss: 0.3278
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8637 - loss: 0.3495 - val_accuracy: 0.8654 - val_loss: 0.3252
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8594 - loss: 0.3530 - val_accuracy: 0.8703 - val_loss: 0.3224
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8619 - loss: 0.3518 - val_accuracy: 0.8654 - val_loss: 0.3202
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8608 - loss: 0.3475 - val_accuracy: 0.8955 - val_loss: 0.3180
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8681 - loss: 0.3447 - val_accuracy: 0.8714 - val_loss: 0.3148
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8649 - loss: 0.3376 - val_accuracy: 0.8719 - val_loss: 0.3120
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8680 - loss: 0.3347 - val_accuracy: 0.9124 - val_loss: 0.3101
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8763 - loss: 0.3286 - val_accuracy: 0.9059 - val_loss: 0.3074
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8685 - loss: 0.3371 - val_accuracy: 0.8823 - val_loss: 0.3043
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8651 - loss: 0.3390 - val_accuracy: 0.9201 - val_loss: 0.3038
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8770 - loss: 0.3280 - val_accuracy: 0.8998 - val_loss: 0.3000
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8715 - loss: 0.3290 - val_accuracy: 0.9223 - val_loss: 0.2977
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8816 - loss: 0.3202 - val_accuracy: 0.9201 - val_loss: 0.2941
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8818 - loss: 0.3240 - val_accuracy: 0.9288 - val_loss: 0.2922
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8868 - loss: 0.3160 - val_accuracy: 0.9201 - val_loss: 0.2882
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8914 - loss: 0.3134 - val_accuracy: 0.9294 - val_loss: 0.2865
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8876 - loss: 0.3114 - val_accuracy: 0.9223 - val_loss: 0.2827
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8921 - loss: 0.3054 - val_accuracy: 0.9316 - val_loss: 0.2803
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8925 - loss: 0.3051 - val_accuracy: 0.9332 - val_loss: 0.2786
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8942 - loss: 0.3059 - val_accuracy: 0.9354 - val_loss: 0.2762
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9018 - loss: 0.3015 - val_accuracy: 0.9310 - val_loss: 0.2721
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8992 - loss: 0.2959 - val_accuracy: 0.9343 - val_loss: 0.2690
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8972 - loss: 0.2930 - val_accuracy: 0.9294 - val_loss: 0.2666
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8903 - loss: 0.2970 - val_accuracy: 0.9546 - val_loss: 0.2659
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9017 - loss: 0.2973 - val_accuracy: 0.9338 - val_loss: 0.2609
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9093 - loss: 0.2830 - val_accuracy: 0.9469 - val_loss: 0.2586
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9058 - loss: 0.2823 - val_accuracy: 0.9524 - val_loss: 0.2578
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9113 - loss: 0.2865 - val_accuracy: 0.9469 - val_loss: 0.2527
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9135 - loss: 0.2799 - val_accuracy: 0.9349 - val_loss: 0.2510
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9113 - loss: 0.2766 - val_accuracy: 0.9518 - val_loss: 0.2523

# %%
from matplotlib.colors import ListedColormap
# Load the data from the CSV file
data1 = pd.read_csv(r'selected ficher.csv')

# Normalize the data
data1 = tf.keras.utils.normalize(data1, axis=1)

# Predict using the model
predicted = model.predict(data1)

# Convert predicted probabilities to predicted classes
predicted_classes = np.argmax(predicted, axis=1)

# Reshape the predicted classes to match image dimensions
height, width = 1000, 1000
predicted_image = np.reshape(predicted_classes, (height, width))
# Define the custom color palette for each class
colors = ['blue', 'green', 'yellow', 'red']
cmap = ListedColormap(colors)
# Display the image
plt.matshow(predicted_image, cmap=cmap)
plt.colorbar()
plt.show()
# Out:
# 31250/31250 ━━━━━━━━━━━━━━━━━━━━ 54s 2ms/step

# %%
# Predict test data
prediction = np.argmax(model.predict(x_test), axis=1).flatten()

# Confusion matrix
cm = confusion_matrix(y_test, prediction, normalize='true')
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm)
cm_display.plot()
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Calculate Cohen's Kappa for the hybrid model
kappa = cohen_kappa_score(y_test, prediction)
print("Cohen's Kappa for CNN Model:", kappa)

# Calculate accuracy for the hybrid model
accuracy = accuracy_score(y_test, prediction)
print("Accuracy for CNN Model:", accuracy)
# Out:
# Cohen's Kappa for CNN Model: 0.9339073726478735
# Accuracy for CNN Model: 0.9518336070060208

# %%
# Importing necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score,accuracy_score, precision_score, recall_score,confusion_matrix
# Evaluate the model on the validation data
evaluation_results = model.evaluate(x_test_reshaped, y_test)

# Print or use the evaluation results as needed
print("Evaluation Results:", evaluation_results)
# Make predictions using the trained model on the validation data
y_pred = model.predict(x_test)

# Display the shape of the predicted values
print("Shape of Predicted Values:", y_pred.shape)
# Get the indices of the maximum values along axis 1 for predicted values
prediction = np.argmax(y_pred, axis=1)

# Get the indices of the maximum values along axis 1 for actual values (ground truth)
actual = y_test
# Calculating F1 Score using the macro average method
f1 = f1_score(actual, prediction, average='macro')

# Calculating accuracy score
accuracy = accuracy_score(actual, prediction)

# Calculating precision using the macro average method
precision = precision_score(actual, prediction, average='macro')

# Calculating recall using the macro average method
recall = recall_score(actual, prediction, average='macro')

# Printing the computed metrics
print('F1 Score:', f1)
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9472 - loss: 0.2595
# Evaluation Results: [0.2505991756916046, 0.9518336057662964]
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Shape of Predicted Values: (1827, 5)
# F1 Score: 0.9345339577323208
# Accuracy: 0.9518336070060208
# Precision: 0.935307849126769
# Recall: 0.9339432547212434

# %%
plt.plot(result.history['loss'], label='Loss')
plt.plot(result.history['val_loss'], label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(result.history['accuracy'],label='train')### accuracy train
plt.plot(result.history['val_accuracy'],label='test') ### accuracy test
plt.title(' accuracy & Test accuracy')
plt.legend()
plt.show()

# %%
y=result.history['val_accuracy']
epoch=[x for x in range(0,len(y))]
data=pd.DataFrame({'x':epoch,'y':y})
data.to_csv('fscore with ficher xy.csv',index=False)
